# %%
import pandas as pd
import numpy as np
import re

# %%
# !ls forum_data/
# Out:
# forum_node.tsv  forum_users.tsv

# %%
input = 'asdas!,da]sd!. sakdjasd asd./>asdsa?d<'
re.split('[ \.\,\!\?\:\;\"\(\)\<\>\[\]\#\$\=\-\/]', input)
# Out:
# ['asdas', '', 'da', 'sd', '', '', 'sakdjasd', 'asd', '', '', 'asdsa', 'd', '']

# %%
#!/usr/bin/python

import sys
import re

i = 0
first = True
mapper_out = []
for line in open('forum_data/forum_node.tsv', 'r'):
    i += 1
    data = line.split('\t')
    #if len(data) != 19:
    #    continue
    if first:
        first = False
        continue

    # get relevant fields
    node = data[0].strip('"') # remove extra " on node
    body = data[4]    

    # split words on given pattern (all characters escaped)
    # words = re.split('[ \.\,\!\?\:\;\"\(\)\<\>\[\]\#\$\=\-\/]', body)
    words = re.findall('\w+', body)
    words = [w.lower() for w in words if w != '']

    for word in words:
        mapper_out.append("{0}\t{1}".format(word, node))

# %%
mapper_out[:10]
# Out:
# ['whether\t5339',
#  'pdf\t5339',
#  'of\t5339',
#  'unit\t5339',
#  'and\t5339',
#  'homework\t5339',
#  'is\t5339',
#  'available\t5339',
#  'cs101\t5339',
#  'pdf\t5339']

# %%
# sorter
def sorter(data):
    data = [line.split("\t") for line in data]
    sorted_data = sorted(data, key=lambda x: x[0])
    return [('\t').join(line) for line in sorted_data]

sorter_out = sorter(mapper_out)

# %%
r = random.randint(0, len(sorter_out))
sorter_out[r-200:r+200]
# Out:
# ['variables\t17962',
#  'variables\t31225',
#  'variables\t13248',
#  'variables\t13628',
#  'variables\t10593',
#  'variables\t11700',
#  'variables\t11700',
#  'variables\t12264',
#  'variables\t12281',
#  'variables\t27733',
#  'variables\t13101',
#  'variables\t15276',
#  'variables\t14435',
#  'variables\t14380',
#  'variables\t14380',
#  'variables\t14362',
#  'variables\t13980',
#  'variables\t13980',
#  'variables\t21542',
#  'variables\t14566',
#  'variables\t14912',
#  'variables\t19143',
#  'variables\t17161',
#  'variables\t16053',
#  'variables\t16053',
#  'variables\t16345',
#  'variables\t16150',
#  'variables\t16201',
#  'variables\t28959',
#  'variables\t18070',
#  'variables\t18070',
#  'variables\t22692',
#  'variables\t17603',
#  'variables\t28582',
#  'variables\t19935',
#  'variables\t20270',
#  'variables\t20270',
#  'variables\t20980',
#  'variables\t20985',
#  'variables\t20985',
#  'variables\t34387',
#  'variables\t25417',
#  'variables\t22136',
#  'variables\t22136',
#  'variables\t57240',
#  'variables\t23514',
#  'variables\t12881',
#  'variables\t57253',
#  'variables\t31470',
#  'variables\t31470',
#  'variables\t27766',
#  'variables\t28378',
#  'variables\t30354',
#  'variables\t34708',
#  'variables\t29075',
#  'variables\t30492',
#  'variables\t31713',
#  'variables\t31713',
#  'variables\t2045',
#  'variables\t35383',
#  'variables\t6029135',
#  'variables\t6029135',
#  'variables\t36383',
#  'variables\t39181',
#  'variables\t55652',
#  'variables\t2012477',
#  'variables\t2012477',
#  'variables\t2012477',
#  'variables\t36797',
#  'variables\t55815',
#  'variables\t53349',
#  'variables\t5012446',
#  'variables\t51107',
#  'variables\t51235',
#  'variables\t59513',
#  'variables\t56059',
#  'variables\t2007920',
#  'variables\t54940',
#  'variables\t54028',
#  'variables\t54824',
#  'variables\t54824',
#  'variables\t57113',
#  'variables\t59127',
#  'variables\t57258',
#  'variables\t66087',
#  'variables\t66105',
#  'variables\t66079',
#  'variables\t65648',
#  'variables\t64790',
#  'variables\t64661',
#  'variables\t61768',
#  'variables\t61296',
#  'variables\t60192',
#  'variables\t57668',
#  'variables\t56637',
#  'variables\t56637',
#  'variables\t55921',
#  'variables\t55751',
#  'variables\t55384',
#  'variables\t54816',
#  'variables\t54816',
#  'variables\t54635',
#  'variables\t54339',
#  'variables\t53847',
#  'variables\t53121',
#  'variables\t53028',
#  'variables\t52086',
#  'variables\t52005',
#  'variables\t51987',
#  'variables\t51190',
#  'variables\t51190',
#  'variables\t51190',
#  'variables\t51190',
#  'variables\t51119',
#  'variables\t51119',
#  'variables\t50658',
#  'variables\t50482',
#  'variables\t47926',
#  'variables\t47856',
#  'variables\t47804',
#  'variables\t46402',
#  'variables\t46196',
#  'variables\t46196',
#  'variables\t43558',
#  'variables\t42688',
#  'variables\t41144',
#  'variables\t38772',
#  'variables\t38772',
#  'variables\t37813',
#  'variables\t34195',
#  'variables\t32043',
#  'variables\t32019',
#  'variables\t32006',
#  'variables\t31348',
#  'variables\t30719',
#  'variables\t30300',
#  'variables\t30068',
#  'variables\t29898',
#  'variables\t28388',
#  'variables\t27933',
#  'variables\t27533',
#  'variables\t27203',
#  'variables\t23589',
#  'variables\t23583',
#  'variables\t21091',
#  'variables\t21071',
#  'variables\t20981',
#  'variables\t20668',
#  'variables\t20285',
#  'variables\t19498',
#  'variables\t18458',
#  'variables\t18387',
#  'variables\t17960',
#  'variables\t17960',
#  'variables\t17810',
#  'variables\t17696',
#  'variables\t17520',
#  'variables\t16086',
#  'variables\t15339',
#  'variables\t15457',
#  'variables\t15010',
#  'variables\t15005',
#  'variables\t14044',
#  'variables\t14044',
#  'variables\t13539',
#  'variables\t13318',
#  'variables\t13089',
#  'variables\t12147',
#  'variables\t11864',
#  'variables\t10557',
#  'variables\t9523',
#  'variables\t8474',
#  'variables\t8474',
#  'variables\t8081',
#  'variables\t7994',
#  'variables\t5885',
#  'variables\t5885',
#  'variables\t4773',
#  'variables\t4657',
#  'variables\t3881',
#  'variables\t1002828',
#  'variables\t1013980',
#  'variables\t1013980',
#  'variables\t29151',
#  'variables\t1008231',
#  'variables\t32774',
#  'variables\t1027106',
#  'variables\t1007385',
#  'variables\t1003655',
#  'variables\t1006190',
#  'variables\t57078',
#  'variables\t1009779',
#  'variables\t1016549',
#  'variables\t1000193',
#  'variables\t1016811',
#  'variables\t50932',
#  'variables\t50932',
#  'variables\t1022707',
#  'variables\t1017395',
#  'variables\t1006089',
#  'variables\t1019413',
#  'variables\t1019413',
#  'variables\t1025496',
#  'variables\t1021995',
#  'variables\t1023941',
#  'variables\t1023464',
#  'variables\t1025646',
#  'variables\t1035096',
#  'variables\t1034547',
#  'variables\t1029390',
#  'variables\t1028997',
#  'variables\t1028818',
#  'variables\t1028818',
#  'variables\t1026512',
#  'variables\t1026512',
#  'variables\t1026501',
#  'variables\t1026384',
#  'variables\t1026373',
#  'variables\t1026339',
#  'variables\t1024741',
#  'variables\t1024739',
#  'variables\t1024681',
#  'variables\t1024681',
#  'variables\t1024681',
#  'variables\t1024367',
#  'variables\t1023510',
#  'variables\t1024142',
#  'variables\t1024140',
#  'variables\t1024140',
#  'variables\t1024140',
#  'variables\t1024135',
#  'variables\t1024135',
#  'variables\t1024135',
#  'variables\t1024049',
#  'variables\t1024071',
#  'variables\t1024030',
#  'variables\t1023264',
#  'variables\t1023073',
#  'variables\t1022979',
#  'variables\t1022979',
#  'variables\t1022473',
#  'variables\t1021945',
#  'variables\t1021602',
#  'variables\t1021559',
#  'variables\t1018242',
#  'variables\t1018196',
#  'variables\t1016810',
#  'variables\t1016699',
#  'variables\t1014572',
#  'variables\t1014402',
#  'variables\t1013028',
#  'variables\t1012704',
#  'variables\t1011725',
#  'variables\t1011527',
#  'variables\t1010332',
#  'variables\t1010187',
#  'variables\t1009802',
#  'variables\t1009752',
#  'variables\t1009727',
#  'variables\t1009538',
#  'variables\t1009527',
#  'variables\t1009496',
#  'variables\t1009299',
#  'variables\t1009058',
#  'variables\t1009058',
#  'variables\t1008855',
#  'variables\t1008814',
#  'variables\t1008813',
#  'variables\t1008693',
#  'variables\t1008418',
#  'variables\t1008255',
#  'variables\t1008255',
#  'variables\t1006083',
#  'variables\t1006024',
#  'variables\t1005986',
#  'variables\t1005496',
#  'variables\t1005174',
#  'variables\t1004559',
#  'variables\t1004410',
#  'variables\t1003730',
#  'variables\t1003277',
#  'variables\t1003277',
#  'variables\t1002998',
#  'variables\t1002990',
#  'variables\t1002990',
#  'variables\t1002990',
#  'variables\t1002888',
#  'variables\t1002888',
#  'variables\t1002455',
#  'variables\t1002444',
#  'variables\t1002210',
#  'variables\t1002055',
#  'variables\t1001840',
#  'variables\t2015982',
#  'variables\t2008235',
#  'variables\t2008235',
#  'variables\t23836',
#  'variables\t23836',
#  'variables\t5001151',
#  'variables\t5009561',
#  'variables\t2019370',
#  'variables\t2001013',
#  'variables\t1002985',
#  'variables\t2015585',
#  'variables\t2008664',
#  'variables\t2008664',
#  'variables\t9005196',
#  'variables\t2019804',
#  'variables\t2019804',
#  'variables\t2002966',
#  'variables\t10001870',
#  'variables\t10001870',
#  'variables\t10001870',
#  'variables\t10008980',
#  'variables\t10008980',
#  'variables\t10008980',
#  'variables\t10009575',
#  'variables\t10011530',
#  'variables\t2000429',
#  'variables\t2013630',
#  'variables\t2013525',
#  'variables\t2014012',
#  'variables\t2004005',
#  'variables\t1024365',
#  'variables\t1024365',
#  'variables\t1024365',
#  'variables\t1024309',
#  'variables\t1024309',
#  'variables\t1024309',
#  'variables\t2018159',
#  'variables\t2018159',
#  'variables\t2017779',
#  'variables\t2017670',
#  'variables\t2017379',
#  'variables\t2017113',
#  'variables\t2016762',
#  'variables\t2016104',
#  'variables\t2014870',
#  'variables\t2013805',
#  'variables\t2013523',
#  'variables\t2013242',
#  'variables\t2013220',
#  'variables\t2012941',
#  'variables\t2011483',
#  'variables\t2010095',
#  'variables\t2010085',
#  'variables\t2010085',
#  'variables\t2010085',
#  'variables\t2010085',
#  'variables\t2009873',
#  'variables\t2009865',
#  'variables\t2008474',
#  'variables\t2008287',
#  'variables\t2008220',
#  'variables\t2008219',
#  'variables\t2007935',
#  'variables\t2007301',
#  'variables\t2006333',
#  'variables\t2005933',
#  'variables\t2005932',
#  'variables\t2005354',
#  'variables\t2004287',
#  'variables\t2003734',
#  'variables\t2003542',
#  'variables\t2002334',
#  'variables\t2001263',
#  'variables\t2001123',
#  'variables\t1006440',
#  'variables\t1006440',
#  'variables\t3001884',
#  'variables\t3000195',
#  'variables\t3000288',
#  'variables\t3000298',
#  'variables\t5003331',
#  'variables\t1023142',
#  'variables\t1002468',
#  'variables\t5008958',
#  'variables\t5003335',
#  'variables\t5001722',
#  'variables\t5001722',
#  'variables\t5001961',
#  'variables\t5001135',
#  'variables\t5012447',
#  'variables\t5010540',
#  'variables\t5005743',
#  'variables\t5006266',
#  'variables\t5006266',
#  'variables\t5006817',
#  'variables\t5006838',
#  'variables\t5012079',
#  'variables\t5009839',
#  'variables\t1012496',
#  'variables\t5013721',
#  'variables\t5014904',
#  'variables\t5012503',
#  'variables\t5012439',
#  'variables\t5010624',
#  'variables\t5009536',
#  'variables\t5009456',
#  'variables\t5008429']

# %%
reducer_out = []
reverted_index = set()
total = 0
oldKey = None

for line in sorter_out:
    data_mapped = line.strip().split("\t")
    if len(data_mapped) != 2:
        # Something has gone wrong. Skip this line.
        continue
        
    thisKey, thisValue = data_mapped
    thisValue = int(thisValue)

    if oldKey and oldKey != thisKey:
        if oldKey == 'fantastic' or oldKey == 'fantastically':
            indexes = list(reverted_index)
            indexes.sort()
            reducer_out.append("{0}\t{1}\t{2}".format(oldKey, total, indexes))
        oldKey = thisKey
        total = 1
        reverted_index = set([thisValue])

    total += 1
    if thisValue not in reverted_index:
        reverted_index.add(thisValue)

    oldKey = thisKey

# %%
reducer_out
# Out:
# ['fantastic\t130\t[2209, 6090, 9508, 15556, 20063, 23898, 27209, 27711, 36163, 38820, 38883, 39980, 40231, 40488, 41912, 48820, 51804, 52447, 55132, 56956, 58673, 59895, 62630, 66083, 66505, 1000431, 1001506, 1005894, 1006084, 1007576, 1007608, 1007853, 1008261, 1008386, 1010131, 1010498, 1011252, 1013270, 1013419, 1013991, 1014021, 1016782, 1016815, 1016835, 1016994, 1025636, 1027001, 1028457, 1028874, 1030230, 1030729, 1031110, 1032109, 1032115, 1033658, 1034207, 1034358, 1034438, 1034525, 1034530, 2002998, 2003241, 2003508, 2003840, 2004893, 2011035, 2016461, 2017301, 2017302, 2018301, 2019574, 3000238, 3000468, 4000333, 5005694, 5006500, 5006788, 5009899, 5011288, 5014087, 6002545, 6002673, 6003097, 6004507, 6005344, 6006160, 6007187, 6008386, 6012077, 6016882, 6018124, 6018203, 6018659, 6026982, 6028672, 6028886, 6029575, 6031252, 7000047, 7000790, 7001164, 7001188, 7002333, 7003022, 7003035, 7003318, 7005815, 7005846, 8000280, 8001941, 9000864, 9001403, 9003233, 9003491, 9005356, 10000126, 10000243, 10001673, 10001915, 10003144, 10003797, 10004184, 10004997, 10008829, 10009417, 10010453, 10010957, 11000246, 12000437, 12001776]',
#  'fantastically\t2\t[1007765, 1025821]']
